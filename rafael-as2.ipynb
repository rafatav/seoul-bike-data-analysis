# %% [markdown]
# # Pontifícia Universidade Católica do Paraná
#
# #### Atividade Somativa 2
# #### Aluno: Rafael Oliveira Tavares Pinto
# #### Disciplina: Técnicas de Machine Learning

# %% [markdown]
# ## Introdução
#
# Seoul Bike Data é o dataset a ser analisado nesse trabalho. O dataset contém a quantidade de bicicletas alugadas na cidade de Seul, capital da Coréia do Sul, entre os anos de 2017 e 2018.
# O objetivo desse trabalho é o de analisar e usar as informações mais relevantes retiradas do dataset para realizar uma análise preditiva prevendo a quantidade de bicicletas que serão alugadas em janeiro de 2019.
#
# Começamos o processo importando as bibliotecas do python a serem utilizadas em nossas análises:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as mcm
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Dataset Seoul Bike Data
#
# A seguir leremos o arquivo do dataset em formato excel utilizando a biblioteca pandas e exibiremos as primeiras e últimas fileiras do dataset:

# %%
df = pd.read_excel('seoul_bike_data.xlsx')
df
# Out:
#                  DateTime  Day  Weekday  Hour  Rented Bike Count  \
# 0     2017-01-12 00:00:00   12        5     0                254
# 1     2017-01-12 01:00:00   12        5     1                204
# 2     2017-01-12 02:00:00   12        5     2                173
# 3     2017-01-12 03:00:00   12        5     3                107
# 4     2017-01-12 04:00:00   12        5     4                 78
# ...                   ...  ...      ...   ...                ...
# 8755  2018-12-31 19:00:00   31        2    19                163
# 8756  2018-12-31 20:00:00   31        2    20                161
# 8757  2018-12-31 21:00:00   31        2    21                179
# 8758  2018-12-31 22:00:00   31        2    22                155
# 8759  2018-12-31 23:00:00   31        2    23                227
#
#       Temperature(°C)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# 0                -5.2           37               2.2              2000
# ...

# %%
plt.figure(figsize=(10,5))
plt.scatter(df['Hour'], df['Temperature(°C)'], color=mcm.rainbow(np.linspace(0, 1, 8760)))
